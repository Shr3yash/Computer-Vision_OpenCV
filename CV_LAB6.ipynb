# %% [markdown]
# # Python Code for following Enhancement Operations:
# >1. Plotting a Histogram for an Image
# >2. Linear Stretching
# >3. Histogram Equalization

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('INT.jpg',0)
if img is None:
    print('Could not open or find the image:', INT.jpg)
    exit(0)
cv2.imshow('original',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Equilize Histogram

# %%
def EquiH():
    dst = cv2.equalizeHist(img)
    cv2.imshow('Source image', img)
    cv2.imshow('Equalized Image', dst)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    return dst

# %% [markdown]
# ## Display equilized histograms of both images

# %%
def HO():
    histg = cv2.calcHist([img],[0],None,[256],[0,256]) 
    plt.plot(histg)
    plt.show()
    return plt

# %%
def HN():
    dst = cv2.equalizeHist(img)
    histg = cv2.calcHist([dst],[0],None,[256],[0,256]) 
    plt.plot(histg)
    plt.show()
    return plt

# %% [markdown]
# ## Linear stretching

# %% [markdown]
# >Min-Max Stretching, the lower and upper values of the input image are made to span the full dynamic range.
# In other words, Lower value of the input image is mapped to 0 and the upper value is mapped to 255.

# %%
def strI():
    # Create zeros array to store the stretched image
    minmax_img = np.zeros((img.shape[0],img.shape[1]),dtype = 'uint8')

    # Loop over the image and apply Min-Max formulae
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            minmax_img[i,j] = 255*(img[i,j]-np.min(img))/(np.max(img)-np.min(img))

    return minmax_img

# %%
def strH():
    # Create zeros array to store the stretched image
    minmax_img = np.zeros((img.shape[0],img.shape[1]),dtype = 'uint8')

    # Loop over the image and apply Min-Max formulae
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            minmax_img[i,j] = 255*(img[i,j]-np.min(img))/(np.max(img)-np.min(img))
            
    histg = cv2.calcHist([minmax_img],[0],None,[256],[0,256]) 
    plt.plot(histg)
    plt.show()
    return plt

# %% [markdown]
# ### This is the default case when user puts unbounded input this gets executed

# %%
def default():
    return "Incorrect Input"

# %% [markdown]
# ### Driver program

# %%
while True:
    print("\tMenu:\n\
           1. Display Histogram Equilized Image \n\
           2. Display Original Histogram \n\
           3. Display Equlized Histogram \n\
           4. Display Linear stretched Image \n\
           5. Display Linear stretched Histogram \n\
           0. Exit\n")
    c = int(input(print("Enter your Choices from above")))
    
    if c == 1:
        final_img=EquiH()
       
       
    elif c == 2:
        final_img=HO()
       
       
    elif c == 3:
        final_img=HN()
       
        
    elif c == 4:
        final_img=strI()
        
       
    elif c == 5:
        final_img=strH()
        
       
    elif c == 0:
        break
    else :
        default()
        break
# Out:
# 	Menu:
#            1. Display Histogram Equilized Image
#            2. Display Original Histogram
#            3. Display Equlized Histogram
#            4. Display Linear stretched Image
#            5. Display Linear stretched Histogram
#            0. Exit
#
# Enter your Choices from above
# None1
# 	Menu:
#            1. Display Histogram Equilized Image
#            2. Display Original Histogram
#            3. Display Equlized Histogram
#            4. Display Linear stretched Image
#            5. Display Linear stretched Histogram
#            0. Exit
#
# Enter your Choices from above
# None2
# 	Menu:
#            1. Display Histogram Equilized Image
#            2. Display Original Histogram
#            3. Display Equlized Histogram
#            4. Display Linear stretched Image
#            5. Display Linear stretched Histogram
#            0. Exit
#
# Enter your Choices from above
# None3
# 	Menu:
#            1. Display Histogram Equilized Image
# ...
